# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")

# %%
df_test = pd.read_csv("data/test.csv")

# %%
df = df[~df.action_type.isin(['filter selection', 'change of sort order', 'search for poi', 'search for destination'])]
df_test = df_test[~df_test.action_type.isin(['filter selection', 'change of sort order', 'search for poi', 'search for destination'])]

# %%
from keras.preprocessing.sequence import pad_sequences
    
for idx, row in df_test.groupby("session_id"):
    print(type(lastRow['reference']))
    if type(lastRow['reference']) == float:
        break
    else:
        print(row['referece'])
        lastRow = row.iloc[-1]
# Out:
# <class 'float'>

# %%
a = [1,2,3]
b = [5,6,7]
for i, (_a, _b) in enumerate(zip(a,b)):
    print(i,_a, _b)
# Out:
# 0 1 5
# 1 2 6
# 2 3 7

# %%
a = np.array([[2],[2]])

# %%
a = df_test[df_test.groupby("session_id").cumcount(ascending=False) > 0]

# %%
a
# Out:
#               user_id     session_id   timestamp  step  \
# 0        004A07DM0IDW  1d688ec168932  1541555614     1
# 1        004A07DM0IDW  1d688ec168932  1541555614     2
# 2        004A07DM0IDW  1d688ec168932  1541555696     3
# 3        004A07DM0IDW  1d688ec168932  1541555707     4
# 4        004A07DM0IDW  1d688ec168932  1541555717     5
# 5        004A07DM0IDW  1d688ec168932  1541555792     6
# 7        009RGHI3G9A3  f05ab0de907e2  1541570935     1
# 9        00Y1Z24X8084  26b6d294d66e7  1541651766     1
# 14       01V3WDTDM5CU  07628a0f5be0b  1541575516     4
# 17       02AOAVF9PVYH  4a01c3afbc224  1541680083     2
# 18       02AOAVF9PVYH  4a01c3afbc224  1541680083     3
# 19       02AOAVF9PVYH  4a01c3afbc224  1541680085     4
# 20       02AOAVF9PVYH  4a01c3afbc224  1541680096     5
# 23       02AOAVF9PVYH  4a01c3afbc224  1541680261     8
# 24       02AOAVF9PVYH  4a01c3afbc224  1541680261     9
# 25       02AOAVF9PVYH  4a01c3afbc224  1541680271    10
# ...

# %%
df_test
# Out:
#               user_id     session_id   timestamp  step  \
# 0        004A07DM0IDW  1d688ec168932  1541555614     1
# 1        004A07DM0IDW  1d688ec168932  1541555614     2
# 2        004A07DM0IDW  1d688ec168932  1541555696     3
# 3        004A07DM0IDW  1d688ec168932  1541555707     4
# 4        004A07DM0IDW  1d688ec168932  1541555717     5
# 5        004A07DM0IDW  1d688ec168932  1541555792     6
# 6        004A07DM0IDW  1d688ec168932  1541555799     7
# 7        009RGHI3G9A3  f05ab0de907e2  1541570935     1
# 8        009RGHI3G9A3  f05ab0de907e2  1541570940     2
# 9        00Y1Z24X8084  26b6d294d66e7  1541651766     1
# 10       00Y1Z24X8084  26b6d294d66e7  1541651823     2
# 14       01V3WDTDM5CU  07628a0f5be0b  1541575516     4
# 15       01V3WDTDM5CU  07628a0f5be0b  1541575643     5
# 17       02AOAVF9PVYH  4a01c3afbc224  1541680083     2
# 18       02AOAVF9PVYH  4a01c3afbc224  1541680083     3
# 19       02AOAVF9PVYH  4a01c3afbc224  1541680085     4
# ...

# %%
df_test[df_test.session_id == "01c887f2453ff"]
# Out:
#            user_id     session_id   timestamp  step             action_type  \
# 2089  3HKZ9Q2GXF3L  01c887f2453ff  1541678631     2  interaction item image
# 2090  3HKZ9Q2GXF3L  01c887f2453ff  1541678631     3  interaction item image
# 2091  3HKZ9Q2GXF3L  01c887f2453ff  1541678641     4  interaction item image
# 2092  3HKZ9Q2GXF3L  01c887f2453ff  1541678641     5  interaction item image
# 2093  3HKZ9Q2GXF3L  01c887f2453ff  1541678641     6  interaction item image
# 2094  3HKZ9Q2GXF3L  01c887f2453ff  1541678641     7  interaction item image
# 2095  3HKZ9Q2GXF3L  01c887f2453ff  1541678651     8  interaction item image
#
#      reference platform            city  device current_filters impressions  \
# 2089    100222       BR  Cancun, Mexico  mobile             NaN         NaN
# 2090    100222       BR  Cancun, Mexico  mobile             NaN         NaN
# 2091    100222       BR  Cancun, Mexico  mobile             NaN         NaN
# ...

# %%
df_test.groupby("session_id").tail(1)[df_test.action_type == "clickout item"][df_test.reference.isna()]
# Out:
# /Users/jarana/anaconda3/envs/recsys2019/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#               user_id     session_id   timestamp  step    action_type  \
# 6        004A07DM0IDW  1d688ec168932  1541555799     7  clickout item
# 8        009RGHI3G9A3  f05ab0de907e2  1541570940     2  clickout item
# 10       00Y1Z24X8084  26b6d294d66e7  1541651823     2  clickout item
# 15       01V3WDTDM5CU  07628a0f5be0b  1541575643     5  clickout item
# 61       02AOAVF9PVYH  4a01c3afbc224  1541681278    46  clickout item
# 109      0339C84S24ET  89171d441a304  1541615683    36  clickout item
# 111      0386OH8JDE1Q  e09591d07cdef  1541620536     2  clickout item
# 115      03LTH89QY623  7663406cf586c  1541554183     4  clickout item
# 138      03VT0ODUTZB0  725e8adf70e86  1541632490    23  clickout item
# ...

# %%
notall = set(_s)

# %%
notall2 = set(_s)

# %%
notall2 - notall
# Out:
# {'9fa00b4381368', 'cbe3752713eee'}

# %%
df_test = df_test.drop([794770, 2255685])

# %%
df_test[df_test.session_id.isin(notall2 - notall)]
# Out:
#               user_id     session_id   timestamp  step  \
# 794764   HDFSLRD2P5IC  cbe3752713eee  1541623639     1
# 794765   HDFSLRD2P5IC  cbe3752713eee  1541623682     2
# 794766   HDFSLRD2P5IC  cbe3752713eee  1541623722     3
# 794767   HDFSLRD2P5IC  cbe3752713eee  1541623725     4
# 794768   HDFSLRD2P5IC  cbe3752713eee  1541624037     5
# 794770   HDFSLRD2P5IC  cbe3752713eee  1541660358     2
# 2255682  VLTF9VIDSG06  9fa00b4381368  1541708371     1
# 2255683  VLTF9VIDSG06  9fa00b4381368  1541708376     2
# 2255684  VLTF9VIDSG06  9fa00b4381368  1541710590     3
# 2255685  VLTF9VIDSG06  9fa00b4381368  1541627924     1
#
#                      action_type reference platform                      city  \
# 794764             clickout item   1258844       IT             Naples, Italy
# 794765             clickout item     21126       IT             Naples, Italy
# 794766     interaction item info     45807       IT             Naples, Italy
# ...

# %%
seq_item, seq_city, seq_action, seq_filter, seq_price, seq_position
for si, srows in df.groupby("session_id"):
    lastRow = srows[-1]
    if lastRow["action_type"] != "clickout item":
        continue
    impressions = 
        
    histRows = srows[:-1]
    
        
        
        
        
    
    gtItem = srows[-1]
    break
# Out:
# 3
# 0 35a3ad727e863
# 3
# 0 d5c40497cb432
# 78
# 0 f44c4ea59074e
